# %% [markdown]
# # Introdução

# %% [markdown]
# ## Importação das bibliotecas necessarias

# %%
# %matplotlib inline
import requests
import pandas as pd
import os
import json
import sys
import matplotlib.pyplot as plt

# %% [markdown]
# ## Funções auxiliares

# %%
df_sif = pd.read_excel(r'../csv_files/Sifilis_congênita_municipio_UF_Região_País_2012_2019.xlsx')
df_sif.columns = df_sif.iloc[0]
df_sif.drop(df_sif.index[0])
df_sif.drop(df_sif.columns[17:], axis=1)
# Out:
# 0                        Município  Código         Nome Município  \
# 0                        Município  Código         Nome Município
# 1     110001 Alta Floresta D'Oeste  110001  Alta Floresta D'Oeste
# 2                 110002 Ariquemes  110002              Ariquemes
# 3                    110003 Cabixi  110003                 Cabixi
# 4                    110004 Cacoal  110004                 Cacoal
# ...                            ...     ...                    ...
# 5653                    2 Nordeste       2               Nordeste
# 5654                     3 Sudeste       3                Sudeste
# 5655                         4 Sul       4                    Sul
# 5656                5 Centro-Oeste       5           Centro-Oeste
# 5657                     55 Brasil      55                 Brasil
#
# 0     Sífilis congênita em menores de um ano Total  \
# 0     Sífilis congênita em menores de um ano Total
# 1                                                2
# ...

# %% [markdown]
# ## Dados de acesso a api

# %% [markdown]
# ### TODO: Decidir qual é a melhor forma de gerar gráficos relativos ao ano escolhido
